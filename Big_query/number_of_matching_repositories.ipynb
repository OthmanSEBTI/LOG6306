# %%
import pandas as pd

query_results1 = pd.read_csv('Bigquery_repositories_results.csv')
query_results1
# Out:
#                                          repo_name  Unnamed: 1  bytes name_1  \
# 0     oktadeveloper/jhipster-microservices-example         NaN   1841   Java
# 1                             houshengbo/openwhisk         NaN   5837   Java
# 2                            sopnopriyo/sopnopriyo         NaN    440   Java
# 3                                      openfl/lime         NaN   1163   Java
# 4                                   MinoGames/lime         NaN   1163   Java
# ...                                            ...         ...    ...    ...
# 3704                     adangel/liquibase-percona         NaN   2406   Java
# 3705                             spinnaker/kayenta         NaN    874   Java
# 3706                 intel-analytics/analytics-zoo         NaN  73165   Java
# 3707                                 apycazo/codex         NaN    144   Java
# 3708                          pgentile/zucchini-ui         NaN    706   Java
#
#       bytes_1
# 0      628198
# ...

# %%
query_results2 = pd.read_csv('Bigquery_repositories_results_only_docker.csv')
query_results2
# Out:
#                              repo_name  \
# 0              bootphon/zerospeech2017
# 1                   gboudreau/Greyhole
# 2                  Clarifai/kubernetes
# 3                       dvdhrm/systemd
# 4                      Hucaru/Valhalla
# ...                                ...
# 21521       ascoderu/opwen-cloudserver
# 21522                nuxis/p0sX-server
# 21523         LuisAlejandro/pipsalabim
# 21524  tyrjola/robotframework-wiremock
# 21525                      mbucc/shmig
#
#                                                 language        name  bytes
# 0      {\n  "language": [{\n    "name": "C",\n    "by...  Dockerfile   1004
# 1      {\n  "language": [{\n    "name": "C",\n    "by...  Dockerfile   1427
# 2      {\n  "language": [{\n    "name": "C",\n    "by...  Dockerfile  52719
# 3      {\n  "language": [{\n    "name": "Awk",\n    "...  Dockerfile   1039
# 4      {\n  "language": [{\n    "name": "Awk",\n    "...  Dockerfile    386
# ...

# %%
studied_projects = pd.read_csv('../Article_Data/Studied Projects - Raw Data.csv')
studied_projects
# Out:
#                              Repository  \
# 0                 alebabai/linden-honey
# 1                   all-of-us/workbench
# 2                       amazeeio/lagoon
# 3                   Artemkaaas/indy-sdk
# 4    aspuru-guzik-group/mission_control
# ..                                  ...
# 63                         Soluto/tweek
# 64          stafli-org/stafli.stack.php
# 65  unbalancedparentheses/docker-erlang
# 66                vietj/vertx-pg-client
# 67                         xhochy/arrow
#
#                                                  Link    KLOC  Stars  \
# 0        https://github.com/linden-honey/linden-honey     4.8      1
# 1              https://github.com/all-of-us/workbench   350.7     21
# 2                  https://github.com/amazeeio/lagoon   253.9    396
# 3              https://github.com/Artemkaaas/indy-sdk   352.5      1
# 4   https://github.com/aspuru-guzik-group/mission_...    87.3      2
# ...

# %%
query_results1[query_results1.repo_name.isin(studied_projects.Repository.tolist())]
print(len(query_results1[query_results1.repo_name.isin(studied_projects.Repository.tolist())]))
# Out:
# 16

# %%
query_results2[query_results2.repo_name.isin(studied_projects.Repository.tolist())]
print(len(query_results2[query_results2.repo_name.isin(studied_projects.Repository.tolist())]))
# Out:
# 28
